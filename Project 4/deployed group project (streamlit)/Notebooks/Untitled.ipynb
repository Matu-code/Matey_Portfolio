# %%
# Importing libraries
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import AffinityPropagation
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.cluster import KMeans 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.inspection import permutation_importance
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# Importing the needed datasets
crime_rate = pd.read_csv("./work/2022-23d-1fcmgt-reg-ai-01-group-team3/data/Misdrijven_per_wijk_en_buurt_per_maand_15052023_134652.csv", sep=";")
df_educational_level = pd.read_csv("./work/2022-23d-1fcmgt-reg-ai-01-group-team3/data/processed/educational_level_neighbourhood_of_Gemeente_Breda_processed.csv", sep=",")
df_income_level = pd.read_csv("./work/2022-23d-1fcmgt-reg-ai-01-group-team3/data/processed/income_level_neighbourhood_of_Gemeente_Breda_processed.csv", sep=",")
df_qol_of_Breda = pd.read_csv('./work/2022-23d-1fcmgt-reg-ai-01-group-team3/data/processed/QOL_of_Gemeente_Breda_processed.csv')
df_region = gpd.read_file('./work/2022-23d-1fcmgt-reg-ai-01-group-team3/data/Buurten.geojson')

# %%
# splitting 'Perioden' into 'Year' and 'month' column
crime_rate['Year'] = crime_rate['Perioden'].str.split(' ').str[0]
crime_rate['month'] = crime_rate['Perioden'].str.split(' ').str[1]
# removing the 'Perioden' column
del crime_rate['Perioden']
crime_rate
# Out:
#                Soort misdrijf        Wijken en buurten
# 0           Totaal misdrijven            Breda centrum  \
# 1           Totaal misdrijven            Breda centrum
# 2           Totaal misdrijven            Breda centrum
# 3           Totaal misdrijven            Breda centrum
# 4           Totaal misdrijven            Breda centrum
# ...                       ...                      ...
# 537603  3.9.3 Fraude (overig)  Buitengebied Teteringen
# 537604  3.9.3 Fraude (overig)  Buitengebied Teteringen
# 537605  3.9.3 Fraude (overig)  Buitengebied Teteringen
# 537606  3.9.3 Fraude (overig)  Buitengebied Teteringen
# 537607  3.9.3 Fraude (overig)  Buitengebied Teteringen
#
#         Geregistreerde misdrijven (aantal)  Year     month
# 0                                    370.0  2012   januari
# 1                                    401.0  2012  februari
# 2                                    375.0  2012     maart
# 3                                    370.0  2012     april
# 4                                    436.0  2012       mei
# ...                                    ...   ...       ...
# 537603                                 0.0  2022  december
# 537604                                 0.0  2023   januari
# 537605                                 0.0  2023  februari
# 537606                                 0.0  2023     maart
# 537607                                 0.0  2023     april
#
# [537608 rows x 5 columns]

# %%
# Filtering the neighbourhoods
def neighborhoods_mask(data, column):
    
    neighborhoods = ['Bavel', 'Belcrum', 'Biesdonk', 'Blauwe Kei', 'Boeimeer',
           'Brabantpark', 'Buitengebied Bavel', 'Buitengebied Prinsenbeek',
           'Buitengebied Ulvenhout', 'Chassé', 'City', 'Doornbos-Linie',
           'Effen-Rith', 'Fellenoord', 'Gageldonk', 'Geeren-noord',
           'Geeren-zuid', 'Ginneken', 'Haagpoort', 'Heilaar', 'Heksenwiel',
           'Heusdenhout', 'Heuvel', 'Kesteren', 'Kievitsloop', 'Kroeten',
           'Krogten', 'Liesbos', 'Mastbos', 'Muizenberg', 'Nieuw Wolfslaar',
           'Overakker', 'Overkroeten', 'Princenhage', 'Prinsenbeek',
           'Ruitersbos', 'Schorsmolen', 'Sportpark', 'Station', 'Steenakker',
           'Teteringen', 'Tuinzigt', 'Ulvenhout', 'Valkenberg', 'Waterdonken',
           'Westerpark', 'Wisselaar', 'Ypelaar', 'Zandberg']
    
    
    mask = data[column].isin(neighborhoods)
    data = data[mask]
    return data

crime_rate = neighborhoods_mask(crime_rate, 'Wijken en buurten')

# %%
# Filtering to only the total crimes
crime_rate = crime_rate[crime_rate['Soort misdrijf'] == 'Totaal misdrijven']
# Renaming the column from 'Wijken en buurten' to 'buurten'
crime_rate = crime_rate.rename(columns = {'Wijken en buurten':'buurten'})
# Aggregating the crime rate for 'Year' and 'buurten'
crime_rate_year = crime_rate.groupby(['Year', 'buurten'], as_index=False)[['Geregistreerde misdrijven (aantal)']].sum()

# %%
# Converting the neighbourhoods labels into integers
le = LabelEncoder()
crime_rate_year['buurten'] = le.fit_transform(crime_rate_year['buurten'])
crime_rate_year = pd.DataFrame(crime_rate_year, columns=crime_rate_year.columns)
buurten = crime_rate_year['buurten']

# %%
crime_rate_year
# Out:
#      Year  buurten  Geregistreerde misdrijven (aantal)
# 0    2012        0                               605.0
# 1    2012        1                               277.0
# 2    2012        2                               470.0
# 3    2012        3                               208.0
# 4    2012        4                               511.0
# ..    ...      ...                                 ...
# 583  2023       44                                 7.0
# 584  2023       45                                28.0
# 585  2023       46                                50.0
# 586  2023       47                                88.0
# 587  2023       48                                69.0
#
# [588 rows x 3 columns]

# %%
# Defining the model
km = KMeans(n_clusters=2, random_state=0, n_init='auto')

# %%
# Taking the unique values of 'Year'
years = crime_rate_year['Year'].unique()

# Creating dataframe to store the results of the clustering model
dataframe_predictions = pd.DataFrame(columns=years)

# The labels for each clusters
cluster_labels = ['Low Crime', 'High Crime']

# Looping through each year, so it can put labels for eaach of them
for year in years:

    # Subsetting to specific year
    crime_rate_year_temp = crime_rate_year[crime_rate_year['Year'] == year].copy()

    # checks whether the dataframe is empty
    if not crime_rate_year_temp.empty:
        # Train and predict the model
        clusters = km.fit_predict(crime_rate_year_temp)
        # Put the clusters in a dataframe
        dataframe_predictions[year] = clusters
        # Put the respective labels
        dataframe_predictions[year] = [cluster_labels[cluster] for cluster in clusters]

        # Insert data into the dataframe
        if year not in dataframe_predictions.columns:
            dataframe_predictions.insert(0, year)
            
# Putting the neighbourhoods in the dataframe
dataframe_predictions['neighborhoods'] = buurten

# %%
# Converting to the previous values of neighbourhoods
dataframe_predictions['neighborhoods'] = le.inverse_transform(dataframe_predictions['neighborhoods'])
dataframe_predictions = dataframe_predictions.set_index('neighborhoods')

# %%
dataframe_predictions
# Out:
#                                 2012        2013        2014        2015
# neighborhoods
# Bavel                     High Crime   Low Crime   Low Crime  High Crime  \
# Belcrum                    Low Crime   Low Crime   Low Crime   Low Crime
# Biesdonk                   Low Crime   Low Crime   Low Crime  High Crime
# Blauwe Kei                 Low Crime   Low Crime   Low Crime   Low Crime
# Boeimeer                   Low Crime   Low Crime   Low Crime   Low Crime
# Brabantpark               High Crime  High Crime  High Crime  High Crime
# Buitengebied Bavel         Low Crime   Low Crime   Low Crime   Low Crime
# Buitengebied Prinsenbeek   Low Crime   Low Crime   Low Crime   Low Crime
# Buitengebied Ulvenhout     Low Crime   Low Crime   Low Crime   Low Crime
# Chassé                    High Crime  High Crime  High Crime  High Crime
# City                      High Crime  High Crime  High Crime  High Crime
# Doornbos-Linie             Low Crime   Low Crime   Low Crime   Low Crime
# Effen-Rith                 Low Crime   Low Crime   Low Crime   Low Crime
# Fellenoord                 Low Crime   Low Crime   Low Crime   Low Crime
# Gageldonk                  Low Crime   Low Crime   Low Crime   Low Crime
# Geeren-noord               Low Crime   Low Crime   Low Crime   Low Crime
# Geeren-zuid                Low Crime   Low Crime   Low Crime   Low Crime
# Ginneken                   Low Crime   Low Crime   Low Crime   Low Crime
# Haagpoort                  Low Crime   Low Crime   Low Crime   Low Crime
# Heilaar                    Low Crime   Low Crime   Low Crime   Low Crime
# Heksenwiel                 Low Crime   Low Crime   Low Crime   Low Crime
# Heusdenhout                Low Crime   Low Crime   Low Crime   Low Crime
# Heuvel                    High Crime   Low Crime  High Crime  High Crime
# Kesteren                   Low Crime   Low Crime   Low Crime   Low Crime
# Kievitsloop                Low Crime   Low Crime   Low Crime   Low Crime
# Kroeten                    Low Crime   Low Crime   Low Crime   Low Crime
# Krogten                    Low Crime   Low Crime   Low Crime   Low Crime
# Liesbos                    Low Crime   Low Crime   Low Crime   Low Crime
# Mastbos                    Low Crime   Low Crime   Low Crime   Low Crime
# Muizenberg                 Low Crime   Low Crime   Low Crime   Low Crime
# Nieuw Wolfslaar            Low Crime   Low Crime   Low Crime   Low Crime
# Overakker                  Low Crime   Low Crime   Low Crime   Low Crime
# Overkroeten                Low Crime   Low Crime   Low Crime   Low Crime
# Princenhage               High Crime   Low Crime   Low Crime  High Crime
# Prinsenbeek               High Crime  High Crime  High Crime  High Crime
# Ruitersbos                 Low Crime   Low Crime   Low Crime   Low Crime
# Schorsmolen                Low Crime   Low Crime   Low Crime   Low Crime
# Sportpark                  Low Crime   Low Crime   Low Crime   Low Crime
# Station                   High Crime   Low Crime  High Crime   Low Crime
# Steenakker                 Low Crime   Low Crime   Low Crime   Low Crime
# Teteringen                High Crime   Low Crime  High Crime  High Crime
# Tuinzigt                  High Crime  High Crime  High Crime  High Crime
# Ulvenhout                  Low Crime   Low Crime   Low Crime   Low Crime
# Valkenberg                 Low Crime   Low Crime   Low Crime   Low Crime
# Waterdonken                Low Crime   Low Crime   Low Crime   Low Crime
# Westerpark                 Low Crime   Low Crime   Low Crime   Low Crime
# Wisselaar                  Low Crime   Low Crime   Low Crime   Low Crime
# Ypelaar                    Low Crime   Low Crime   Low Crime   Low Crime
# Zandberg                   Low Crime   Low Crime   Low Crime   Low Crime
#
#                                 2016        2017        2018        2019
# neighborhoods
# Bavel                     High Crime  High Crime  High Crime   Low Crime  \
# Belcrum                   High Crime  High Crime  High Crime  High Crime
# Biesdonk                  High Crime  High Crime  High Crime  High Crime
# Blauwe Kei                 Low Crime   Low Crime   Low Crime   Low Crime
# Boeimeer                  High Crime  High Crime   Low Crime   Low Crime
# Brabantpark               High Crime  High Crime  High Crime  High Crime
# Buitengebied Bavel         Low Crime   Low Crime   Low Crime   Low Crime
# Buitengebied Prinsenbeek   Low Crime   Low Crime   Low Crime   Low Crime
# Buitengebied Ulvenhout     Low Crime   Low Crime   Low Crime   Low Crime
# Chassé                    High Crime  High Crime  High Crime  High Crime
# City                      High Crime  High Crime  High Crime  High Crime
# Doornbos-Linie             Low Crime  High Crime   Low Crime   Low Crime
# Effen-Rith                 Low Crime   Low Crime   Low Crime   Low Crime
# Fellenoord                 Low Crime   Low Crime   Low Crime   Low Crime
# Gageldonk                  Low Crime   Low Crime   Low Crime   Low Crime
# Geeren-noord               Low Crime   Low Crime   Low Crime   Low Crime
# Geeren-zuid                Low Crime   Low Crime   Low Crime   Low Crime
# Ginneken                   Low Crime   Low Crime   Low Crime   Low Crime
# Haagpoort                  Low Crime   Low Crime   Low Crime   Low Crime
# Heilaar                    Low Crime   Low Crime   Low Crime   Low Crime
# Heksenwiel                 Low Crime   Low Crime   Low Crime   Low Crime
# Heusdenhout                Low Crime   Low Crime   Low Crime   Low Crime
# Heuvel                    High Crime  High Crime  High Crime  High Crime
# Kesteren                   Low Crime   Low Crime   Low Crime   Low Crime
# Kievitsloop                Low Crime   Low Crime   Low Crime   Low Crime
# Kroeten                    Low Crime   Low Crime   Low Crime   Low Crime
# Krogten                    Low Crime   Low Crime  High Crime   Low Crime
# Liesbos                    Low Crime   Low Crime   Low Crime   Low Crime
# Mastbos                    Low Crime   Low Crime   Low Crime   Low Crime
# Muizenberg                 Low Crime   Low Crime   Low Crime   Low Crime
# Nieuw Wolfslaar            Low Crime   Low Crime   Low Crime   Low Crime
# Overakker                  Low Crime   Low Crime   Low Crime   Low Crime
# Overkroeten                Low Crime   Low Crime   Low Crime   Low Crime
# Princenhage               High Crime  High Crime  High Crime  High Crime
# Prinsenbeek               High Crime  High Crime  High Crime  High Crime
# Ruitersbos                 Low Crime   Low Crime   Low Crime   Low Crime
# Schorsmolen               High Crime  High Crime  High Crime  High Crime
# Sportpark                  Low Crime   Low Crime   Low Crime   Low Crime
# Station                   High Crime  High Crime  High Crime  High Crime
# Steenakker                 Low Crime   Low Crime   Low Crime   Low Crime
# Teteringen                High Crime  High Crime  High Crime  High Crime
# Tuinzigt                  High Crime  High Crime  High Crime  High Crime
# Ulvenhout                  Low Crime  High Crime   Low Crime   Low Crime
# Valkenberg                High Crime  High Crime   Low Crime   Low Crime
# Waterdonken                Low Crime   Low Crime   Low Crime   Low Crime
# Westerpark                 Low Crime   Low Crime   Low Crime   Low Crime
# Wisselaar                  Low Crime   Low Crime   Low Crime   Low Crime
# Ypelaar                    Low Crime   Low Crime   Low Crime   Low Crime
# Zandberg                   Low Crime   Low Crime   Low Crime   Low Crime
#
#                                 2020        2021        2022        2023
# neighborhoods
# Bavel                     High Crime  High Crime  High Crime   Low Crime
# Belcrum                   High Crime  High Crime  High Crime  High Crime
# Biesdonk                  High Crime  High Crime  High Crime  High Crime
# Blauwe Kei                 Low Crime   Low Crime   Low Crime   Low Crime
# Boeimeer                  High Crime  High Crime   Low Crime   Low Crime
# Brabantpark               High Crime  High Crime  High Crime  High Crime
# Buitengebied Bavel         Low Crime   Low Crime   Low Crime   Low Crime
# Buitengebied Prinsenbeek   Low Crime   Low Crime   Low Crime   Low Crime
# Buitengebied Ulvenhout     Low Crime   Low Crime   Low Crime   Low Crime
# Chassé                    High Crime  High Crime  High Crime  High Crime
# City                      High Crime  High Crime  High Crime  High Crime
# Doornbos-Linie            High Crime  High Crime  High Crime   Low Crime
# Effen-Rith                 Low Crime   Low Crime   Low Crime   Low Crime
# Fellenoord                 Low Crime   Low Crime   Low Crime   Low Crime
# Gageldonk                  Low Crime   Low Crime   Low Crime   Low Crime
# Geeren-noord               Low Crime   Low Crime   Low Crime   Low Crime
# Geeren-zuid                Low Crime   Low Crime   Low Crime   Low Crime
# Ginneken                   Low Crime  High Crime   Low Crime   Low Crime
# Haagpoort                  Low Crime   Low Crime   Low Crime   Low Crime
# Heilaar                    Low Crime   Low Crime   Low Crime   Low Crime
# Heksenwiel                 Low Crime   Low Crime   Low Crime   Low Crime
# Heusdenhout                Low Crime   Low Crime   Low Crime   Low Crime
# Heuvel                    High Crime  High Crime  High Crime  High Crime
# Kesteren                   Low Crime   Low Crime   Low Crime   Low Crime
# Kievitsloop                Low Crime   Low Crime   Low Crime   Low Crime
# Kroeten                    Low Crime   Low Crime   Low Crime   Low Crime
# Krogten                   High Crime  High Crime  High Crime   Low Crime
# Liesbos                    Low Crime   Low Crime   Low Crime   Low Crime
# Mastbos                    Low Crime   Low Crime   Low Crime   Low Crime
# Muizenberg                 Low Crime   Low Crime   Low Crime   Low Crime
# Nieuw Wolfslaar            Low Crime   Low Crime   Low Crime   Low Crime
# Overakker                  Low Crime   Low Crime   Low Crime   Low Crime
# Overkroeten                Low Crime   Low Crime   Low Crime   Low Crime
# Princenhage               High Crime  High Crime  High Crime   Low Crime
# Prinsenbeek               High Crime  High Crime  High Crime  High Crime
# Ruitersbos                 Low Crime   Low Crime   Low Crime   Low Crime
# Schorsmolen               High Crime  High Crime  High Crime  High Crime
# Sportpark                  Low Crime   Low Crime   Low Crime   Low Crime
# Station                   High Crime  High Crime  High Crime  High Crime
# Steenakker                 Low Crime   Low Crime   Low Crime   Low Crime
# Teteringen                High Crime  High Crime  High Crime   Low Crime
# Tuinzigt                  High Crime  High Crime  High Crime  High Crime
# Ulvenhout                 High Crime  High Crime   Low Crime   Low Crime
# Valkenberg                 Low Crime   Low Crime   Low Crime   Low Crime
# Waterdonken                Low Crime   Low Crime   Low Crime   Low Crime
# Westerpark                 Low Crime   Low Crime   Low Crime   Low Crime
# Wisselaar                  Low Crime   Low Crime   Low Crime   Low Crime
# Ypelaar                    Low Crime  High Crime   Low Crime   Low Crime
# Zandberg                   Low Crime   Low Crime   Low Crime   Low Crime

# %%
# Taking the labels for 2020
crime_predictions_2020 = dataframe_predictions['2020']

# %%
df_educational_level['Buurten'].unique()
# Out:
# array(['Valkenberg', 'Chassé', 'Fellenoord', 'Schorsmolen', 'Station',
#        'City', 'Belcrum', 'Doornbos-Linie', 'Biesdonk', 'Geeren-zuid',
#        'Wisselaar', 'Krogten', 'Geeren-noord', 'Waterdonken',
#        'Brabantpark', 'Sportpark', 'Zandberg', 'Heusdenhout',
#        'Moleneind-oost', 'Hoogeind', 'Blauwe Kei', 'Ypelaar', 'Overakker',
#        'Ginneken', 'Mastbos', 'Boeimeer', 'Ruitersbos', 'Haagpoort',
#        'Heuvel', 'Tuinzigt', 'Princenhage', 'Westerpark', 'Heilaar',
#        'Hazeldonk', 'Steenakker', 'Effen-Rith', 'Liesbos', 'Gageldonk',
#        'Kievitsloop', 'Kesteren', 'Muizenberg', 'Heksenwiel',
#        'Overkroeten', 'Kroeten', 'Emer', 'Hagebeemd', 'Bavel',
#        'Nieuw Wolfslaar', 'Buitengebied Bavel', 'Ulvenhout',
#        'Buitengebied Ulvenhout', 'Prinsenbeek',
#        'Buitengebied Prinsenbeek', 'Teteringen', 'Vuchtpolder',
#        'Buitengebied Teteringen'], dtype=object)

# %%
df_income_level['Buurten'].unique()
# Out:
# array(['Valkenberg', 'Chassé', 'Fellenoord', 'Schorsmolen', 'Station',
#        'City', 'Belcrum', 'Doornbos-Linie', 'Biesdonk', 'Geeren-zuid',
#        'Wisselaar', 'Krogten', 'Geeren-noord', 'Waterdonken',
#        'Brabantpark', 'Sportpark', 'Zandberg', 'Heusdenhout',
#        'Moleneind-oost', 'Hoogeind', 'Blauwe Kei', 'Ypelaar', 'Overakker',
#        'Ginneken', 'Mastbos', 'Boeimeer', 'Ruitersbos', 'Haagpoort',
#        'Heuvel', 'Tuinzigt', 'Princenhage', 'Westerpark', 'Heilaar',
#        'Hazeldonk', 'Steenakker', 'Effen-Rith', 'Liesbos', 'Gageldonk',
#        'Kievitsloop', 'Kesteren', 'Muizenberg', 'Heksenwiel',
#        'Overkroeten', 'Kroeten', 'Emer', 'Hagebeemd', 'Bavel',
#        'Nieuw Wolfslaar', 'Buitengebied Bavel', 'Ulvenhout',
#        'Buitengebied Ulvenhout', 'Prinsenbeek',
#        'Buitengebied Prinsenbeek', 'Teteringen', 'Vuchtpolder',
#        'Buitengebied Teteringen'], dtype=object)

# %%
df_qol_of_Breda['Buurten'].unique()
# Out:
# array(['Valkenberg', 'Chassé', 'Fellenoord', 'Schorsmolen', 'Station',
#        'City', 'Belcrum', 'Doornbos-Linie', 'Biesdonk', 'Geeren-zuid',
#        'Wisselaar', 'Krogten', 'Geeren-noord', 'Waterdonken',
#        'Brabantpark', 'Sportpark', 'Zandberg', 'Heusdenhout',
#        'Moleneind-oost', 'Hoogeind', 'Blauwe Kei', 'Ypelaar', 'Overakker',
#        'Ginneken', 'Mastbos', 'Boeimeer', 'Ruitersbos', 'Haagpoort',
#        'Heuvel', 'Tuinzigt', 'Princenhage', 'Westerpark', 'Heilaar',
#        'Hazeldonk', 'Steenakker', 'Effen-Rith', 'Liesbos', 'Gageldonk',
#        'Kievitsloop', 'Kesteren', 'Muizenberg', 'Heksenwiel',
#        'Overkroeten', 'Kroeten', 'Emer', 'Hagebeemd', 'Bavel',
#        'Nieuw Wolfslaar', 'Buitengebied Bavel', 'Ulvenhout',
#        'Buitengebied Ulvenhout', 'Prinsenbeek',
#        'Buitengebied Prinsenbeek', 'Teteringen', 'Vuchtpolder',
#        'Buitengebied Teteringen'], dtype=object)

# %%
df_educational_level.columns
# Out:
# Index(['Unnamed: 0', 'Buurten', 'level_of_education', 'Year', 'value'], dtype='object')

# %%
df_educational_level = df_educational_level.drop('Unnamed: 0', axis=1)

# %%
# Subsetting the data to 2020
df_educational_level_year = df_educational_level[df_educational_level['Year'] == 2020]

# Convert the categorical column 'level_of_education' to three new columns
df_educational_level_year = (df_educational_level_year.pivot(index='Buurten', columns='level_of_education')
                                            .stack(level=0)
                                            .rename_axis(index=['Buurten', 'Year'], columns=None)
                                            ).reset_index()
# Dropping the unnecessary columns
df_educational_level_year = df_educational_level_year[df_educational_level_year['Year'] != 'Year']
df_educational_level_year = df_educational_level_year.drop(['Year', ' Midden'], axis=1)

# %%
df_income_level = df_income_level.drop('Unnamed: 0', axis=1)

# %%
# Subsetting the data to 2020
df_income_level_year = df_income_level[df_income_level['Year'] == 2020]

# Convert the categorical column 'level_of_income' to two new columns
df_income_level_year = (df_income_level_year.pivot(index='Buurten', columns='level_of_income')
                                            .stack(level=0)
                                            .rename_axis(index=['Buurten', 'Year'], columns=None)
                                            ).reset_index()

# Dropping the unnecessary columns
df_income_level_year = df_income_level_year[df_income_level_year['Year'] != 'Year']
df_income_level_year = df_income_level_year.drop('Year', axis=1)

# %%
df_income_level_year
# Out:
#                       Buurten  High income  Low income
# 1                       Bavel         32,0        26,0
# 3                     Belcrum         27,0        36,0
# 5                    Biesdonk          7,0        55,0
# 7                  Blauwe Kei         27,0        29,0
# 9                    Boeimeer         31,0        33,0
# 11                Brabantpark         12,0        55,0
# 13         Buitengebied Bavel         57,0        14,0
# 15   Buitengebied Prinsenbeek         47,0        18,0
# 17    Buitengebied Teteringen            ?           ?
# 19     Buitengebied Ulvenhout         39,0        24,0
# 21                     Chassé         18,0        46,0
# 23                       City         11,0        63,0
# 25             Doornbos-Linie          9,0        57,0
# 27                 Effen-Rith         43,0        15,0
# 29                       Emer            ?           ?
# 31                 Fellenoord          4,0        71,0
# 33                  Gageldonk         19,0        33,0
# 35               Geeren-noord          7,0        63,0
# 37                Geeren-zuid          4,0        66,0
# 39                   Ginneken         40,0        25,0
# 41                  Haagpoort         14,0        57,0
# 43                  Hagebeemd            ?           ?
# 45                  Hazeldonk            ?           ?
# 47                    Heilaar         55,0        21,0
# 49                 Heksenwiel         26,0        35,0
# 51                Heusdenhout         17,0        47,0
# 53                     Heuvel         10,0        54,0
# 55                   Hoogeind            ?           ?
# 57                   Kesteren         13,0        41,0
# 59                Kievitsloop         19,0        26,0
# 61                    Kroeten         32,0        21,0
# 63                    Krogten         21,0        44,0
# 65                    Liesbos         48,0        16,0
# 67                    Mastbos         44,0        29,0
# 69             Moleneind-oost            ?           ?
# 71                 Muizenberg         21,0        33,0
# 73            Nieuw Wolfslaar         49,0        16,0
# 75                  Overakker         25,0        35,0
# 77                Overkroeten         31,0        31,0
# 79                Princenhage         22,0        37,0
# 81                Prinsenbeek         32,0        24,0
# 83                 Ruitersbos         34,0        36,0
# 85                Schorsmolen          4,0        69,0
# 87                  Sportpark         31,0        27,0
# 89                    Station         14,0        55,0
# 91                 Steenakker         14,0        74,0
# 93                 Teteringen         35,0        24,0
# 95                   Tuinzigt          7,0        63,0
# 97                  Ulvenhout         36,0        26,0
# 99                 Valkenberg         10,0        63,0
# 101               Vuchtpolder            ?           ?
# 103               Waterdonken         39,0        20,0
# 105                Westerpark         35,0        27,0
# 107                 Wisselaar          7,0        51,0
# 109                   Ypelaar         16,0        43,0
# 111                  Zandberg         34,0        34,0

# %%
df_qol_of_Breda = df_qol_of_Breda.drop('Unnamed: 0', axis=1)
df_qol_of_Breda_year = df_qol_of_Breda[df_qol_of_Breda['Year'] == 2020]

# %%
df_qol_of_Breda_year
# Out:
#                       Buurten  Year      value
# 112                Valkenberg  2020  4,1224382
# 113                    Chassé  2020  4,2117509
# 114                Fellenoord  2020  3,9870623
# 115               Schorsmolen  2020  3,9446339
# 116                   Station  2020  4,0620225
# 117                      City  2020  4,1370920
# 118                   Belcrum  2020  4,0524916
# 119            Doornbos-Linie  2020  3,9201641
# 120                  Biesdonk  2020  3,8748954
# 121               Geeren-zuid  2020  3,8424682
# 122                 Wisselaar  2020  3,8879320
# 123                   Krogten  2020  4,1688750
# 124              Geeren-noord  2020  3,8312036
# 125               Waterdonken  2020  4,0743781
# 126               Brabantpark  2020  4,1249967
# 127                 Sportpark  2020  4,3294353
# 128                  Zandberg  2020  4,3462661
# 129               Heusdenhout  2020  4,1551773
# 130            Moleneind-oost  2020          ?
# 131                  Hoogeind  2020          ?
# 132                Blauwe Kei  2020  4,2348162
# 133                   Ypelaar  2020  4,1732273
# 134                 Overakker  2020  4,2366705
# 135                  Ginneken  2020  4,3309247
# 136                   Mastbos  2020  4,2551871
# 137                  Boeimeer  2020  4,2301167
# 138                Ruitersbos  2020  4,3157876
# 139                 Haagpoort  2020  3,9937257
# 140                    Heuvel  2020  3,9642746
# 141                  Tuinzigt  2020  3,9579438
# 142               Princenhage  2020  4,2006204
# 143                Westerpark  2020  4,1441579
# 144                   Heilaar  2020  4,3089926
# 145                 Hazeldonk  2020          ?
# 146                Steenakker  2020  3,8895081
# 147                Effen-Rith  2020  4,1965436
# 148                   Liesbos  2020  4,2461532
# 149                 Gageldonk  2020  4,0586048
# 150               Kievitsloop  2020  4,0504400
# 151                  Kesteren  2020  3,9843782
# 152                Muizenberg  2020  4,0444092
# 153                Heksenwiel  2020  4,0742179
# 154               Overkroeten  2020  4,0447931
# 155                   Kroeten  2020  4,0710483
# 156                      Emer  2020          ?
# 157                 Hagebeemd  2020  4,3401180
# 158                     Bavel  2020  4,2286584
# 159           Nieuw Wolfslaar  2020  4,2704295
# 160        Buitengebied Bavel  2020  4,2934189
# 161                 Ulvenhout  2020  4,2601497
# 162    Buitengebied Ulvenhout  2020  4,2476167
# 163               Prinsenbeek  2020  4,1980640
# 164  Buitengebied Prinsenbeek  2020  4,2747239
# 165                Teteringen  2020  4,2748255
# 166               Vuchtpolder  2020  4,3157208
# 167   Buitengebied Teteringen  2020  4,4683443

# %%
# Merging the data together
Breda_2020 = pd.merge(df_educational_level_year, df_income_level_year, on='Buurten')
Breda_2020 = pd.merge(Breda_2020, df_qol_of_Breda_year, on='Buurten')

# %%
Breda_2020.columns
# Out:
# Index(['Buurten', ' Hoog', ' Laag', ' High income', ' Low income', 'Year',
#        'value'],
#       dtype='object')

# %%
# Filtering the data to the rows with the missing values
Breda_2020_missing = Breda_2020[Breda_2020[' High income'] == '?']
# Filtering the data to the rows without the missing values
Breda_2020 = Breda_2020[Breda_2020[' High income'] != '?']

# %%
Breda_2020_missing
# Out:
#                     Buurten  Hoog  Laag  High income  Low income  Year
# 8   Buitengebied Teteringen    50    60            ?           ?  2020  \
# 14                     Emer     ?     ?            ?           ?  2020
# 21                Hagebeemd    90    40            ?           ?  2020
# 22                Hazeldonk     ?     ?            ?           ?  2020
# 27                 Hoogeind     0    10            ?           ?  2020
# 34           Moleneind-oost    30     0            ?           ?  2020
# 50              Vuchtpolder    10    30            ?           ?  2020
#
#         value
# 8   4,4683443
# 14          ?
# 21  4,3401180
# 22          ?
# 27          ?
# 34          ?
# 50  4,3157208

# %%
Breda_2020 = Breda_2020.drop('Year', axis=1)

# %%
columns = [' High income', ' Low income', 'value']

# Replacing the ',' with '.' and converting the columns into float
for column in columns:
    Breda_2020[column] = Breda_2020[column].str.replace(',', '.').astype(float)

# Renaming the columns in English
Breda_2020 = Breda_2020.rename(columns={'Buurten': 'neighborhoods',
                                        ' Hoog': 'high_education',
                                        ' Laag': 'low_education',
                                        ' High income': 'high_income',
                                        ' Low income': 'low_income',
                                        'value': 'livability_index'})

# %%
Breda_2020
# Out:
#                neighborhoods high_education low_education  high_income
# 0                      Bavel           1520           810         32.0  \
# 1                    Belcrum           1580           520         27.0
# 2                   Biesdonk            720          1480          7.0
# 3                 Blauwe Kei           1310           590         27.0
# 4                   Boeimeer           2360           640         31.0
# 5                Brabantpark           2880          1950         12.0
# 6         Buitengebied Bavel            190           100         57.0
# 7   Buitengebied Prinsenbeek            200           120         47.0
# 9     Buitengebied Ulvenhout             80            40         39.0
# 10                    Chassé           1870           230         18.0
# 11                      City           1020           230         11.0
# 12            Doornbos-Linie           1260           960          9.0
# 13                Effen-Rith            230           150         43.0
# 15                Fellenoord            390           430          4.0
# 16                 Gageldonk           1360           840         19.0
# 17              Geeren-noord            290           790          7.0
# 18               Geeren-zuid            470          1240          4.0
# 19                  Ginneken           2360           540         40.0
# 20                 Haagpoort            640           590         14.0
# 23                   Heilaar            170            70         55.0
# 24                Heksenwiel           1050           950         26.0
# 25               Heusdenhout           1210           960         17.0
# 26                    Heuvel           1640          2200         10.0
# 28                  Kesteren            650          1010         13.0
# 29               Kievitsloop           1020           820         19.0
# 30                   Kroeten            680           370         32.0
# 31                   Krogten             60            50         21.0
# 32                   Liesbos            230           110         48.0
# 33                   Mastbos            240           170         44.0
# 35                Muizenberg            670           740         21.0
# 36           Nieuw Wolfslaar            870           360         49.0
# 37                 Overakker           1150           410         25.0
# 38               Overkroeten            800           520         31.0
# 39               Princenhage           2450          1700         22.0
# 40               Prinsenbeek           2850          1840         32.0
# 41                Ruitersbos            890           200         34.0
# 42               Schorsmolen           1520           390          4.0
# 43                 Sportpark           1350           320         31.0
# 44                   Station           1060           280         14.0
# 45                Steenakker            130            40         14.0
# 46                Teteringen           2430          1270         35.0
# 47                  Tuinzigt           1560          2020          7.0
# 48                 Ulvenhout           1560           600         36.0
# 49                Valkenberg            800           240         10.0
# 51               Waterdonken            620            90         39.0
# 52                Westerpark           1050           570         35.0
# 53                 Wisselaar            510          1360          7.0
# 54                   Ypelaar           1560           940         16.0
# 55                  Zandberg           2340           410         34.0
#
#     low_income  livability_index
# 0         26.0          4.228658
# 1         36.0          4.052492
# 2         55.0          3.874895
# 3         29.0          4.234816
# 4         33.0          4.230117
# 5         55.0          4.124997
# 6         14.0          4.293419
# 7         18.0          4.274724
# 9         24.0          4.247617
# 10        46.0          4.211751
# 11        63.0          4.137092
# 12        57.0          3.920164
# 13        15.0          4.196544
# 15        71.0          3.987062
# 16        33.0          4.058605
# 17        63.0          3.831204
# 18        66.0          3.842468
# 19        25.0          4.330925
# 20        57.0          3.993726
# 23        21.0          4.308993
# 24        35.0          4.074218
# 25        47.0          4.155177
# 26        54.0          3.964275
# 28        41.0          3.984378
# 29        26.0          4.050440
# 30        21.0          4.071048
# 31        44.0          4.168875
# 32        16.0          4.246153
# 33        29.0          4.255187
# 35        33.0          4.044409
# 36        16.0          4.270429
# 37        35.0          4.236670
# 38        31.0          4.044793
# 39        37.0          4.200620
# 40        24.0          4.198064
# 41        36.0          4.315788
# 42        69.0          3.944634
# 43        27.0          4.329435
# 44        55.0          4.062023
# 45        74.0          3.889508
# 46        24.0          4.274826
# 47        63.0          3.957944
# 48        26.0          4.260150
# 49        63.0          4.122438
# 51        20.0          4.074378
# 52        27.0          4.144158
# 53        51.0          3.887932
# 54        43.0          4.173227
# 55        34.0          4.346266

# %%
# Converting to inegers
Breda_2020['high_education'] = Breda_2020['high_education'].astype(int)
Breda_2020['low_education'] = Breda_2020['low_education'].astype(int)

# %%
Breda_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 0 to 55
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   neighborhoods     49 non-null     object
#  1   high_education    49 non-null     int64
#  2   low_education     49 non-null     int64
#  3   high_income       49 non-null     float64
#  4   low_income        49 non-null     float64
#  5   livability_index  49 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 2.7+ KB

# %%
# Correlation matrix for the data
def correlation_matrix(data):

    # Taking only the numeric data from the dataset
    numeric_data = data.select_dtypes(include=np.number)

    # Defining the correlation matrix
    corr_matrix = numeric_data.corr(method='pearson')

    # Creating the figure for the matrix
    fig, ax = plt.subplots(figsize=(15, 15))
    sns.heatmap(corr_matrix,
               mask=np.triu(corr_matrix),
               ax=ax, annot=True).set_title(f'pearson correlation')

# %%
correlation_matrix(Breda_2020)

# %%
crime_rate['buurten'].sort_values().unique()
# Out:
# array(['Bavel', 'Belcrum', 'Biesdonk', 'Blauwe Kei', 'Boeimeer',
#        'Brabantpark', 'Buitengebied Bavel', 'Buitengebied Prinsenbeek',
#        'Buitengebied Ulvenhout', 'Chassé', 'City', 'Doornbos-Linie',
#        'Effen-Rith', 'Fellenoord', 'Gageldonk', 'Geeren-noord',
#        'Geeren-zuid', 'Ginneken', 'Haagpoort', 'Heilaar', 'Heksenwiel',
#        'Heusdenhout', 'Heuvel', 'Kesteren', 'Kievitsloop', 'Kroeten',
#        'Krogten', 'Liesbos', 'Mastbos', 'Muizenberg', 'Nieuw Wolfslaar',
#        'Overakker', 'Overkroeten', 'Princenhage', 'Prinsenbeek',
#        'Ruitersbos', 'Schorsmolen', 'Sportpark', 'Station', 'Steenakker',
#        'Teteringen', 'Tuinzigt', 'Ulvenhout', 'Valkenberg', 'Waterdonken',
#        'Westerpark', 'Wisselaar', 'Ypelaar', 'Zandberg'], dtype=object)

# %%
Breda_2020['neighborhoods'].unique()
# Out:
# array(['Bavel', 'Belcrum', 'Biesdonk', 'Blauwe Kei', 'Boeimeer',
#        'Brabantpark', 'Buitengebied Bavel', 'Buitengebied Prinsenbeek',
#        'Buitengebied Ulvenhout', 'Chassé', 'City', 'Doornbos-Linie',
#        'Effen-Rith', 'Fellenoord', 'Gageldonk', 'Geeren-noord',
#        'Geeren-zuid', 'Ginneken', 'Haagpoort', 'Heilaar', 'Heksenwiel',
#        'Heusdenhout', 'Heuvel', 'Kesteren', 'Kievitsloop', 'Kroeten',
#        'Krogten', 'Liesbos', 'Mastbos', 'Muizenberg', 'Nieuw Wolfslaar',
#        'Overakker', 'Overkroeten', 'Princenhage', 'Prinsenbeek',
#        'Ruitersbos', 'Schorsmolen', 'Sportpark', 'Station', 'Steenakker',
#        'Teteringen', 'Tuinzigt', 'Ulvenhout', 'Valkenberg', 'Waterdonken',
#        'Westerpark', 'Wisselaar', 'Ypelaar', 'Zandberg'], dtype=object)

# %%
# Filtering the neighbourhoods to the same
df_region = df_region[['BUURT', 'geometry']]

df_region = neighborhoods_mask(df_region, 'BUURT')

# %%
Breda_2020 = pd.merge(Breda_2020, df_region, left_on='neighborhoods', right_on='BUURT')

# %%
Breda_2020 = Breda_2020.drop('BUURT', axis=1)

# %%
Breda_2020.columns
# Out:
# Index(['neighborhoods', 'high_education', 'low_education', 'high_income',
#        'low_income', 'livability_index', 'geometry'],
#       dtype='object')

# %%
Breda_2020
# Out:
#                neighborhoods  high_education  low_education  high_income
# 0                      Bavel            1520            810         32.0  \
# 1                    Belcrum            1580            520         27.0
# 2                   Biesdonk             720           1480          7.0
# 3                 Blauwe Kei            1310            590         27.0
# 4                   Boeimeer            2360            640         31.0
# 5                Brabantpark            2880           1950         12.0
# 6         Buitengebied Bavel             190            100         57.0
# 7   Buitengebied Prinsenbeek             200            120         47.0
# 8     Buitengebied Ulvenhout              80             40         39.0
# 9                     Chassé            1870            230         18.0
# 10                      City            1020            230         11.0
# 11            Doornbos-Linie            1260            960          9.0
# 12                Effen-Rith             230            150         43.0
# 13                Fellenoord             390            430          4.0
# 14                 Gageldonk            1360            840         19.0
# 15              Geeren-noord             290            790          7.0
# 16               Geeren-zuid             470           1240          4.0
# 17                  Ginneken            2360            540         40.0
# 18                 Haagpoort             640            590         14.0
# 19                   Heilaar             170             70         55.0
# 20                Heksenwiel            1050            950         26.0
# 21               Heusdenhout            1210            960         17.0
# 22                    Heuvel            1640           2200         10.0
# 23                  Kesteren             650           1010         13.0
# 24               Kievitsloop            1020            820         19.0
# 25                   Kroeten             680            370         32.0
# 26                   Krogten              60             50         21.0
# 27                   Liesbos             230            110         48.0
# 28                   Mastbos             240            170         44.0
# 29                Muizenberg             670            740         21.0
# 30           Nieuw Wolfslaar             870            360         49.0
# 31                 Overakker            1150            410         25.0
# 32               Overkroeten             800            520         31.0
# 33               Princenhage            2450           1700         22.0
# 34               Prinsenbeek            2850           1840         32.0
# 35                Ruitersbos             890            200         34.0
# 36               Schorsmolen            1520            390          4.0
# 37                 Sportpark            1350            320         31.0
# 38                   Station            1060            280         14.0
# 39                Steenakker             130             40         14.0
# 40                Teteringen            2430           1270         35.0
# 41                  Tuinzigt            1560           2020          7.0
# 42                 Ulvenhout            1560            600         36.0
# 43                Valkenberg             800            240         10.0
# 44               Waterdonken             620             90         39.0
# 45                Westerpark            1050            570         35.0
# 46                 Wisselaar             510           1360          7.0
# 47                   Ypelaar            1560            940         16.0
# 48                  Zandberg            2340            410         34.0
#
#     low_income  livability_index
# 0         26.0          4.228658  \
# 1         36.0          4.052492
# 2         55.0          3.874895
# 3         29.0          4.234816
# 4         33.0          4.230117
# 5         55.0          4.124997
# 6         14.0          4.293419
# 7         18.0          4.274724
# 8         24.0          4.247617
# 9         46.0          4.211751
# 10        63.0          4.137092
# 11        57.0          3.920164
# 12        15.0          4.196544
# 13        71.0          3.987062
# 14        33.0          4.058605
# 15        63.0          3.831204
# 16        66.0          3.842468
# 17        25.0          4.330925
# 18        57.0          3.993726
# 19        21.0          4.308993
# 20        35.0          4.074218
# 21        47.0          4.155177
# 22        54.0          3.964275
# 23        41.0          3.984378
# 24        26.0          4.050440
# 25        21.0          4.071048
# 26        44.0          4.168875
# 27        16.0          4.246153
# 28        29.0          4.255187
# 29        33.0          4.044409
# 30        16.0          4.270429
# 31        35.0          4.236670
# 32        31.0          4.044793
# 33        37.0          4.200620
# 34        24.0          4.198064
# 35        36.0          4.315788
# 36        69.0          3.944634
# 37        27.0          4.329435
# 38        55.0          4.062023
# 39        74.0          3.889508
# 40        24.0          4.274826
# 41        63.0          3.957944
# 42        26.0          4.260150
# 43        63.0          4.122438
# 44        20.0          4.074378
# 45        27.0          4.144158
# 46        51.0          3.887932
# 47        43.0          4.173227
# 48        34.0          4.346266
#
#                                              geometry
# 0   POLYGON ((4.83781 51.56766, 4.83759 51.56661, ...
# 1   POLYGON ((4.78190 51.59764, 4.78187 51.59728, ...
# 2   POLYGON ((4.79155 51.60815, 4.79156 51.60813, ...
# 3   POLYGON ((4.80149 51.57475, 4.80127 51.57461, ...
# 4   POLYGON ((4.77733 51.58081, 4.77741 51.58051, ...
# 5   POLYGON ((4.81860 51.59364, 4.81828 51.59366, ...
# 6   POLYGON ((4.87119 51.56827, 4.87135 51.56790, ...
# 7   POLYGON ((4.71504 51.61456, 4.71637 51.61265, ...
# 8   POLYGON ((4.79976 51.53723, 4.79953 51.53714, ...
# 9   POLYGON ((4.78630 51.58690, 4.78298 51.58366, ...
# 10  POLYGON ((4.78082 51.58951, 4.78107 51.58902, ...
# 11  POLYGON ((4.81098 51.60048, 4.81101 51.60023, ...
# 12  POLYGON ((4.73840 51.55319, 4.73864 51.55251, ...
# 13  POLYGON ((4.77365 51.58514, 4.77367 51.58399, ...
# 14  POLYGON ((4.74990 51.60624, 4.74906 51.60609, ...
# 15  POLYGON ((4.80323 51.61222, 4.80267 51.61103, ...
# 16  POLYGON ((4.81098 51.60048, 4.79667 51.60200, ...
# 17  POLYGON ((4.79291 51.56377, 4.79252 51.56325, ...
# 18  POLYGON ((4.76590 51.58318, 4.76538 51.58180, ...
# 19  POLYGON ((4.74169 51.59271, 4.74161 51.59264, ...
# 20  POLYGON ((4.74139 51.62899, 4.74713 51.62784, ...
# 21  POLYGON ((4.82923 51.59268, 4.82853 51.59194, ...
# 22  POLYGON ((4.76037 51.57604, 4.75990 51.57390, ...
# 23  POLYGON ((4.72840 51.61261, 4.72904 51.61247, ...
# 24  POLYGON ((4.75141 51.61890, 4.75136 51.61882, ...
# 25  POLYGON ((4.73361 51.62737, 4.73536 51.62636, ...
# 26  POLYGON ((4.77804 51.61815, 4.77430 51.61257, ...
# 27  POLYGON ((4.72550 51.57910, 4.72557 51.57892, ...
# 28  POLYGON ((4.78953 51.55290, 4.78953 51.55285, ...
# 29  POLYGON ((4.73906 51.61697, 4.73517 51.61501, ...
# 30  POLYGON ((4.82163 51.56735, 4.82098 51.56416, ...
# 31  POLYGON ((4.81183 51.56596, 4.81192 51.56569, ...
# 32  POLYGON ((4.74139 51.62899, 4.74349 51.62520, ...
# 33  POLYGON ((4.74373 51.57291, 4.74363 51.57176, ...
# 34  POLYGON ((4.72386 51.60229, 4.72386 51.60229, ...
# 35  POLYGON ((4.77850 51.57203, 4.77842 51.57184, ...
# 36  POLYGON ((4.77195 51.58990, 4.77103 51.58887, ...
# 37  POLYGON ((4.80402 51.58156, 4.80539 51.57977, ...
# 38  POLYGON ((4.79127 51.59571, 4.79116 51.59502, ...
# 39  POLYGON ((4.74865 51.59744, 4.74854 51.59731, ...
# 40  POLYGON ((4.81921 51.62183, 4.82073 51.62174, ...
# 41  POLYGON ((4.77130 51.59264, 4.76856 51.59152, ...
# 42  POLYGON ((4.80097 51.55739, 4.80105 51.55735, ...
# 43  POLYGON ((4.78814 51.59321, 4.78819 51.59320, ...
# 44  POLYGON ((4.80703 51.61150, 4.80659 51.60604, ...
# 45  POLYGON ((4.75111 51.59256, 4.75093 51.59079, ...
# 46  POLYGON ((4.79288 51.61445, 4.79168 51.61218, ...
# 47  POLYGON ((4.81604 51.57149, 4.81286 51.56910, ...
# 48  POLYGON ((4.79025 51.57751, 4.79046 51.57720, ...

# %%
# Creating a geopandas dataframe so it can be plotted maps
Breda_2020 = gpd.GeoDataFrame(Breda_2020, geometry='geometry')

# %%
columns = ['high_education', 'low_education', 'high_income',
       'low_income', 'livability_index']

# Specifying the number of columns and rows for the vizualizations
num_subplots = len(columns)
num_cols = 2  
num_rows = (num_subplots + num_cols - 1) // num_cols

# Creating the figure and the axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 10))

# It helps for removing the unneccessary visualizations
num_empty_subplots = (num_rows * num_cols) - num_subplots

# Loops through all columns
for i, column in enumerate(columns):

    # It calculates the index for rows and columns
    row_index = i // num_cols
    col_index = i % num_cols

    # Creating plot for each column
    Breda_2020.plot(column=column,
                    legend=True, 
                    legend_kwds={"label": f'Map for {column}', "orientation": "horizontal"},
                    ax = axes[row_index][col_index])

# Check for empty visualizations
if num_empty_subplots > 0:
    for i in range(num_empty_subplots):
        fig.delaxes(axes[num_rows-1][num_cols-1-i])
        
# Plots the figure
plt.tight_layout()
plt.show()

# %%
# Breda_2020.to_csv('./work/2022-23d-1fcmgt-reg-ai-01-group-team3/data/Breda_2020.csv', index=False)

# %%
# Defining cross validation
kf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# %%
# Separating features
X = Breda_2020.drop(['neighborhoods', 'geometry'], axis=1)
# Defining the Target Values
y = crime_predictions_2020

# Lists to store predictions, scores of the models and the models
accs = []
models = []
predictions = []
# Looping through all n_splits of the cross validation
for train_index, val_index in kf.split(X, y):

    # Splitting into training and validation data for feature
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    # Splitting into training and validation data for target values
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # Defining a classfier
    knn = KNeighborsClassifier()
    # Training the model
    knn.fit(X_train, y_train)
    # Storing the models in a list
    models.append(knn)

for model in models:
    # Predicting the model
    y_pred = knn.predict(X_val)
    # Storing predictions
    predictions.append(y_pred)
    # Calculating the accuracy of the model
    acc = accuracy_score(y_val, y_pred)
    # Storing the results into a list
    accs.append(acc)
    
# The average of the accuracies
mean_acc = acc.mean()
print(mean_acc)
# Out:
# 0.875

# %%
perm_importance = permutation_importance(knn, X_val, y_val, random_state=42)

# Getting the feature importances and their indices
importances = perm_importance.importances_mean
indices = np.argsort(importances)[::-1]

# Plotting the feature importances
plt.figure(figsize=(10, 6))
plt.title("Feature Importance (Permutation Importance)")
plt.bar(range(X.shape[1]), importances[indices])
plt.xticks(range(X.shape[1]), X.columns[indices])
plt.show()
